# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
for i in range(1, 11):
    data1 = pd.read_csv(f'results/test8/run_{i}.csv')
    data2 = pd.read_csv('presentation-plots/data/test7.csv')
    data2 = data2[['device_id', 'test_date', 'test_time', 'fit_R2_LTP', 'fit_R2_LTD']]

    mergedData = pd.merge(data1, data2, on=['device_id', 'test_date', 'test_time'])

    mergedData.to_csv(f'presentation-plots/data/test8/run_{i}.csv', index=False)
